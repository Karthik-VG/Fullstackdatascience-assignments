# %% [markdown]
# #          FULL STACK DATA SCIENCE
#
#
#
#     ASSIGNMENT 1

# %%
1. What are the differences between operators and values in the following?
*
'hello'
-87.8
-
/
+
6

# %% [markdown]
# operators-operators are used to make perform some operations between two values(+,-,*,/..etc)
# values-values are the ones which gets operated by operators(numbers,strings..etc)
# eg:2 + 3 = 5  here 2 and 3 are values,"+" is an operator
#
#
#       *,-,/,+      --> operators
#       'hello',-87.8,6  --> values

# %%
2. What is the difference between string and variable?
spam
'spam'

# %% [markdown]
# string is a datatype.There are frequently using 3 datatypes in python.they are int,float,str.
# variable is a identity which is used to store a value
#
# spam(variable)='spam'(string)

# %%
3. Describe three different data forms.

# %% [markdown]
# int,float,str
# int-integer values whole number , a=10 \n
# float-number with decimal points ,b=1.111 \n
# str-string ,s="ineuron"

# %%
4. What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# The expression is made up of variable,value and operator.
# The function of expression is to get evaluated by the (python) interpreter

# %%
5. In this chapter, assignment statements such as spam = 10 were added. What's the
difference between a declaration and an expression?

# %% [markdown]
# declaration means assigning values to the variable eg..spam=10...
# expression is made up of variable,value,operator and calling any inbuilt function eg..print(spam*20)

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

# %% [markdown]
# bacon = 22
# bacon + 1  #23 not updated to bacon only used
# print(bacon) # 22

# %%
7. What should the values of the following two terms be?

'spam'+'spamspam'
'spam'*3

# %% [markdown]
# 'spam'+'spamspam' == spamspamspam here + acts as a concat for str
# 'spam'*3 == 'spamspamspam'  in python * operator with string make multiply number of times the string

# %%
8. Why is it that eggs is a true variable name but 100 is not?

# %% [markdown]
# The variable has certain rules such as variable name doesn't start with number,there is no space given between the variable
# we can use underscore instead space eg..first_name='ineuron'
# eggs=100  # correct
# 100='eggs' # not correct and we get syntax error

# %%
9. Which of the following three functions may be used to convert a value to an integer, a
floating-point number, or a string?

# %% [markdown]
# int(  ),float(  ),str(  )
# these there are the functions used to convert a variable to integer,floating point number and string
# int(2.1)   # 2
# float(2)   # 2.0
# str(1)     # '1'

# %%
10. What is the error caused by this expression? What would you do about it?

'I have eaten'; + 99 + 'burritos'

# %% [markdown]
# if we run as same as above we get a typeerror,we can concatenate only str with str                                             so we have to convert the integer or float to string and we have to make perform this operation
#
#
#
# 'I have eaten'; + str(99) + 'burritos'
