# %% [markdown]
# # Python basic assignment 1

# %% [markdown]
# 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
print("The addision of a+b is",a+b)
print("The addision of a+b is",a/b)
# Out:
# enter the number6
# enter the number3
# The addision of a+b is 9
# The addision of a+b is 2.0

# %% [markdown]
# 3. Write a Python program to find the area of a triangle?

# %%
breath=int(input("enter the breath"))
height=int(input("enter the height"))
Areaoftriangle=1/2*breath*height
print(Areaoftriangle)
# Out:
# enter the breath6
# enter the height5
# 15.0

# %% [markdown]
# 4. Write a Python program to swap two variables?

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
print("Before swapping")
print("value of a is",a,"value of b is",b)
a,b=b,a
print("After swapping")
print("value of a is",a,"value of b is",b)
# Out:
# enter the number5
# enter the number4
# Before swapping
# value of a is 5 value of b is 4
# After swapping
# value of a is 4 value of b is 5

# %% [markdown]
# 5. Write a Python program to generate a random number?

# %%
import random

# %%
random.randint(1,10)
# Out:
# 3

# %%
random.random()
# Out:
# 0.9654987712014537
