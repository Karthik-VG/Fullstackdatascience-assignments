# %% [markdown]
# # ASSIGNMENT 5

# %% [markdown]
# 1. What does an empty dictionary&#39;s code look like?

# %%
#A empty dictionary represented by a open and close curly brackets ({})
a={}
print(type(a))
# Out:
# <class 'dict'>

# %%
{} #dictionary
# Out:
# {}

# %% [markdown]
# 2. What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?

# %%
dictionary1={"foo":42} #foo--key 42--value

# %%
dictionary1["foo"]
# Out:
# 42

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?

# %%
#list In list the data are arranged in order.We can access elements using index value
list1=[1,2,3,4,"foo","off"]
list1[4]
# Out:
# 'foo'

# %%
#Dictioanry In dictionary the datas are stored in key value pair.We can get elements by using their unique key values
dictionary2={"one":1,"two":2,"three":3}
dictionary2["two"]
# Out:
# 2

# %% [markdown]
# 4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %%
spam={'bar':100}

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-9b5a94d1de8d> in <module>
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %%
#When we access dictionary with undefined key we get key error

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.keys()?

# %%
spam={"cat":"meow"}

# %%
'cat' in spam
# Out:
# True

# %%
'cat' in spam.keys()
# Out:
# True

# %%
#Both expressions are correct.Both check that there is key present or not

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.values()?

# %%
'cat' in spam # here it check with key
# Out:
# True

# %%
'cat' in spam.values() #here it check in the values..So that we are getting False
# Out:
# False

# %% [markdown]
# 7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;] = &#39;black&#39;

# %%
if 'color' not in spam:
    spam['color']='black'

# %%
spam['color']='black'

# %%
spam['color']  #even this statements add the key and value if there is no same key before...If it present before the value got updated
# Out:
# 'black'

# %%
spam.setdefault('color',"black") #This function is used to set key and value default
# Out:
# 'black'

# %%
spam
# Out:
# {'cat': 'meow', 'color': 'black'}

# %% [markdown]
# 8. How do you &quot;pretty print&quot; dictionary values using which module and function?

# %%
spam.values()
# Out:
# dict_values(['meow', 'black'])

# %%
import pprint
pprint.pprint(spam)   #by using pprint module and pprint function we can print dictioanry
# Out:
# {'cat': 'meow', 'color': 'black'}

# %%
spam
# Out:
# {'cat': 'meow', 'color': 'black'}
